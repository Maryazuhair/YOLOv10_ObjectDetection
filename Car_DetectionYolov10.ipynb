# %%
# !pip install roboflow
# !pip install ultralytics
from roboflow import Roboflow
rf = Roboflow(api_key="YKNPtsTkbUtvVZiJi0gD")
project = rf.workspace("customyolo-6wxew").project("objectdetectionyolo-txiji")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 263.7 kB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 10.3 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.90, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to ObjectdetectionYOLO-1 in yolov8:: 100%|██████████| 156/156 [00:00<00:00, 3596.70it/s]

# %%
from ultralytics import YOLO
# Train a custom model
model = YOLO("yolov10n.pt")
model.train(data="/content/ObjectdetectionYOLO-1/data.yaml", epochs=30, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.90 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

results = model.predict("/content/ObjectdetectionYOLO-1/test/images/yt-Gr0HpDM8Ki8-0023_jpg.rf.e11eca48f227346742a5383555a61832.jpg")

results[0].plot()

results[0].save()

predicted_image_path = results[0].path
img = Image.open(predicted_image_path)

plt.figure(figsize=(10, 10))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/ObjectdetectionYOLO-1/test/images/yt-Gr0HpDM8Ki8-0023_jpg.rf.e11eca48f227346742a5383555a61832.jpg: 640x640 4 cars, 339.9ms
# Speed: 5.2ms preprocess, 339.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
